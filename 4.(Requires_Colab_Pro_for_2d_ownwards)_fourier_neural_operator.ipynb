# %% [markdown]
# Source : https://github.com/zongyi-li/fourier_neural_operator

# %% [markdown]
# Requirement: Turn on GPU at runtimne
#
# You need to authorize google drive access for downloading dataset.
#
# Also, you need additional RAM runtime with Colab Pro for 2d onwards (code 2)

# %% [markdown]
# Git Clone files

# %%
# !git clone https://github.com/zongyi-li/fourier_neural_operator.git
# Out:
# Cloning into 'fourier_neural_operator'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 174 (delta 7), reused 17 (delta 7), pack-reused 156
# Receiving objects: 100% (174/174), 70.55 KiB | 252.00 KiB/s, done.
# Resolving deltas: 100% (89/89), done.

# %%
# %cd fourier_neural_operator
# !ls
# Out:
# /content/fourier_neural_operator/fourier_neural_operator
# Adam.py		 fourier_2d.py	     lowrank_1d.py	 README.md
# data_generation  fourier_2d_time.py  lowrank_2d.py	 scripts
# FNO-torch.1.6	 fourier_3d.py	     lowrank_2d_time.py  utilities3.py
# fourier_1d.py	 LICENSE	     lowrank_3d.py

# %% [markdown]
# Download Dataset

# %%
# !mkdir data
# %cd data
# !pwd
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#https://drive.google.com/file/d/16a8od4vidbiNR3WtaBPCSZ0T3moxjhYe/view?usp=sharing
file_id = '16a8od4vidbiNR3WtaBPCSZ0T3moxjhYe' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('burger.zip')
# !unzip burger.zip
# %cd ..
# Out:
# /content/fourier_neural_operator/fourier_neural_operator/data
# /content/fourier_neural_operator/fourier_neural_operator/data
# Archive:  burger.zip
#   inflating: burgers_data_R10.mat
# /content/fourier_neural_operator/fourier_neural_operator

# %% [markdown]
# Running codes 1. Fourier_1d

# %%
# !python fourier_1d.py
# Out:
# 549569
# 0 9.500108297999986 0.05657362458994612 0.33394574534893035 0.06045842528343201
# 1 0.6231431709999242 0.0011101131801842712 0.04657839506864548 0.04162606775760651
# 2 0.5938862819999713 0.0006010678401798941 0.03697525721788406 0.025987002849578857
# 3 0.6004679180000494 0.0004915767333295662 0.03519497087597847 0.019371177852153778
# 4 0.5978301559999863 0.0003441990067221923 0.02976713353395462 0.03880391955375671
# 5 0.5916090449999274 0.0002197438891744241 0.021714977443218233 0.020562816858291626
# 6 0.6122863209998286 0.00018711076627369038 0.021858918756246567 0.016077839732170106
# 7 0.5972273239999595 0.0001447473408552469 0.018437963634729385 0.014584401845932007
# 8 0.5852164660000199 0.00022824171115644277 0.026499070405960085 0.02911505401134491
# 9 0.5967163149998669 0.00022949447396968024 0.026502558737993242 0.018444869816303253
# 10 0.5966848169998684 9.267427598388168e-05 0.014894810125231743 0.018764202892780305
# ...

# %% [markdown]
# Downloading data 2 (Fourier 2d)

# %%
# %cd data
# !pwd

#https://drive.google.com/file/d/1Z1uxG9R8AdAGJprG5STcphysjm56_0Jf/view?usp=sharing
file_id = '1Z1uxG9R8AdAGJprG5STcphysjm56_0Jf' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('Darcy_421.zip')
# !unzip Darcy_421.zip

# !ls
# %cd ..
# Out:
# /content/fourier_neural_operator/fourier_neural_operator/data
# /content/fourier_neural_operator/fourier_neural_operator/data
# Archive:  Darcy_421.zip
#   inflating: piececonst_r421_N1024_smooth2.mat
#   inflating: piececonst_r421_N1024_smooth1.mat
# burgers_data_R10.mat  piececonst_r421_N1024_smooth1.mat
# burger.zip	      piececonst_r421_N1024_smooth2.mat
# Darcy_421.zip
# /content/fourier_neural_operator/fourier_neural_operator

# %% [markdown]
# Running Code 2 ( Not enough ram in collab normal.Runs on Colab Pro with additional RAM runtime)

# %%
# !python fourier_2d.py
# Out:
# tcmalloc: large alloc 1451966464 bytes == 0x67c4000 @  0x7ff9c543e1e7 0x4a3940 0x5b438c 0x7ff9295d48ba 0x7ff9298329c6 0x7ff929832012 0x7ff92983cc8d 0x7ff92983ae84 0x7ff929831647 0x59b1b0 0x515655 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x548ae9 0x51566f 0x593dd7 0x511e2c 0x549e0e 0x4bcb19 0x532b86 0x594a96 0x515600 0x549576 0x604173 0x5f5506
# tcmalloc: large alloc 1451966464 bytes == 0x5dc7c000 @  0x7ff9c543e1e7 0x4a3940 0x5b438c 0x7ff9295d48ba 0x7ff9298329c6 0x7ff929832012 0x7ff92983cc8d 0x7ff92983ae84 0x7ff929831647 0x59b1b0 0x515655 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x548ae9 0x51566f 0x593dd7 0x511e2c 0x549e0e 0x4bcb19 0x532b86 0x594a96 0x515600 0x549576 0x604173 0x5f5506
# ...

# %% [markdown]
# Downloading data 3 (Fourier 2d time)

# %%
# %cd data
# !pwd
# !rm -rf *
#https://drive.google.com/file/d/1pr_Up54tNADCGhF8WLvmyTfKlCD5eEkI/view?usp=sharing
#file_id = '1pr_Up54tNADCGhF8WLvmyTfKlCD5eEkI' # URL id. 
#downloaded = drive.CreateFile({'id': file_id})
#downloaded.GetContentFile('data3.zip')
#!unzip data3.zip

#https://drive.google.com/file/d/1r3idxpsHa21ijhlu3QQ1hVuXcqnBTO7d/view?usp=sharing
file_id = '1r3idxpsHa21ijhlu3QQ1hVuXcqnBTO7d' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('data4.zip')
# !unzip data4.zip

#https://drive.google.com/file/d/1RmDQQ-lNdAceLXrTGY_5ErvtINIXnpl3/view?usp=sharing
#file_id = '1RmDQQ-lNdAceLXrTGY_5ErvtINIXnpl3' # URL id. 
#downloaded = drive.CreateFile({'id': file_id})
#downloaded.GetContentFile('data5.zip')
#!unzip data5.zip
# !ls
# %cd ..
# Out:
# /content/fourier_neural_operator/fourier_neural_operator/data
# /content/fourier_neural_operator/fourier_neural_operator/data
# Archive:  data4.zip
#   inflating: ns_V1e-3_N5000_T50.mat
# data4.zip  ns_V1e-3_N5000_T50.mat
# /content/fourier_neural_operator/fourier_neural_operator

# %%
# %cd data
# !cp ns_V1e-3_N5000_T50.mat ns_data_V100_N1000_T50_2.mat
# !mv ns_V1e-3_N5000_T50.mat ns_data_V100_N1000_T50_1.mat
# %cd ..
# Out:
# /content/fourier_neural_operator/fourier_neural_operator/data
# /content/fourier_neural_operator/fourier_neural_operator

# %% [markdown]
# Running Code 3 ( Not enough ram in collab normal.Runs on Colab Pro with additional RAM runtime)

# %%
# !python fourier_2d_time.py
# Out:
# 500 0.001 100 0.5
# tcmalloc: large alloc 4096000000 bytes == 0x5418000 @  0x7fde91bfe1e7 0x7fde214ee0ce 0x7fde21544cf5 0x7fde214f1948 0x5947d6 0x548cc1 0x5127f1 0x549576 0x4bcb19 0x7fde03bf49dc 0x7fde03c0031c 0x59c097 0x594d69 0x53339c 0x4d3969 0x512147 0x593dd7 0x511e2c 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7fde917fbc87 0x5b621a
# tcmalloc: large alloc 4096000000 bytes == 0x7fdcfbdc0000 @  0x7fde91bfe1e7 0x7fde214ee0ce 0x7fde21548726 0x7fde215dd841 0x59b076 0x515655 0x593dd7 0x511e2c 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7fde917fbc87 0x5b621a
# tcmalloc: large alloc 4096000000 bytes == 0x5418000 @  0x7fde91bfe1e7 0x7fde214ee0ce 0x7fde21544cf5 0x7fde214f1948 0x5947d6 0x548cc1 0x5127f1 0x549576 0x4bcb19 0x7fde03bf49dc 0x7fde03c0031c 0x59c097 0x594d69 0x53339c 0x4d3969 0x512147 0x593dd7 0x511e2c 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7fde917fbc87 0x5b621a
# ...
